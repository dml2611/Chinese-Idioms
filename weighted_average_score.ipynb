# %% [markdown]
# <a href="https://colab.research.google.com/github/dml2611/Chinese-Idioms/blob/main/weighted_average_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Libraries
import numpy as np
import pandas as pd

# %%
# Mount the google drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# Initialise the input and output file paths and load the data
path = " "
outfile = " "
data = pd.read_excel(path + " ")

# %%
# Creating separate dataframes for all models
for j in range(1, 10):
  exec(f"mt_{j} = data[['A{j}', 'I{j}', 'F{j}']]")

# %%
# Calculate weighted average human evaluation scores for all models using the formal score  = 0.4 * accuracy + 0.4 * intelligibility score + 0.2 * fluency score
for j in range(1, 10):
  exec(f"mt_{j}['Weighted Average'] = (0.4 * mt_{j}['A{j}']/5 + 0.4 * mt_{j}['I{j}']/5 + 0.2 * mt_{j}['F{j}']/5)")

# %%
# Weighted average scores for Machine Translation System 5
mt_5
# Out:
#     A5  I5  F5  Weighted Average
# 0    3   2   3              0.52
# 1    3   3   3              0.60
# 2    3   1   3              0.44
# 3    3   3   3              0.60
# 4    1   0   3              0.20
# ..  ..  ..  ..               ...
# 95   3   4   3              0.68
# 96   3   1   3              0.44
# 97   4   4   3              0.76
# 98   4   4   3              0.76
# 99   0   3   3              0.36
#
# [100 rows x 4 columns]

# %%
# Weighted average scores for Machine Translation System 7
mt_6
# Out:
#     A6  I6  F6  Weighted Average
# 0    3   2   3              0.52
# 1    3   3   3              0.60
# 2    1   0   2              0.16
# 3    3   2   3              0.52
# 4    1   0   2              0.16
# ..  ..  ..  ..               ...
# 95   1   0   3              0.20
# 96   1   0   3              0.20
# 97   4   4   3              0.76
# 98   3   3   3              0.60
# 99   1   0   0              0.08
#
# [100 rows x 4 columns]

# %%
for j in range(1, 10):
  exec(f"mt_{j}.to_excel(outfile + 'mt_{j}_weighted.xlsx', index = False)")
