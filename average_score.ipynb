# %% [markdown]
# <a href="https://colab.research.google.com/github/dml2611/Chinese-Idioms/blob/main/average_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Libraries
import numpy as np
import pandas as pd

# %%
# Mount the google drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Initialise the input and output file paths and load the data
path = " "
outfile = " "
data = pd.read_excel(path + "file_name")

# %%
# Creating separate dataframes for all models
for j in range(1, 10):
  exec(f"mt_{j} = data[['A{j}', 'I{j}', 'F{j}']]")

# %%
# Calculating the average human evaluation score for all models
for j in range(1, 10):
  exec(f"mt_{j}['Average'] = ((mt_{j}['A{j}'] + 1)/5 +  (mt_{j}['I{j}'] + 1)/5 + (mt_{j}['F{j}'] + 1)/5)/3")
  # Calculate weighted average human evaluation scores for all models using the formal score  = 0.4 * accuracy + 0.4 * intelligibility score + 0.2 * fluency score
  exec(f"mt_{j}['Weighted Average'] = (0.4 * (mt_{j}['A{j}'] + 1)/5 + 0.4 * (mt_{j}['I{j}'] + 1)/5 + 0.2 * (mt_{j}['F{j}'] + 1)/5)")

# %%
# Average human evaluation score for Machine Translation System 5
mt_5
# Out:
#     A5  I5  F5   Average  Weighted Average
# 0    3   2   3  0.733333              0.72
# 1    3   3   3  0.800000              0.80
# 2    3   1   3  0.666667              0.64
# 3    3   3   3  0.800000              0.80
# 4    1   0   3  0.466667              0.40
# ..  ..  ..  ..       ...               ...
# 95   3   4   3  0.866667              0.88
# 96   3   1   3  0.666667              0.64
# 97   4   4   3  0.933333              0.96
# 98   4   4   3  0.933333              0.96
# 99   0   3   3  0.600000              0.56
#
# [100 rows x 5 columns]

# %%
# Average human evaluation score for Machine Translation System 6
mt_6
# Out:
#     A6  I6  F6   Average  Weighted Average
# 0    3   2   3  0.733333              0.72
# 1    3   3   3  0.800000              0.80
# 2    1   0   2  0.400000              0.36
# 3    3   2   3  0.733333              0.72
# 4    1   0   2  0.400000              0.36
# ..  ..  ..  ..       ...               ...
# 95   1   0   3  0.466667              0.40
# 96   1   0   3  0.466667              0.40
# 97   4   4   3  0.933333              0.96
# 98   3   3   3  0.800000              0.80
# 99   1   0   0  0.266667              0.28
#
# [100 rows x 5 columns]

# %%
# Save the average scores for all models
for j in range(1, 10):
  exec(f"mt_{j}.to_excel(outfile + 'mt_{j}_average.xlsx', index = False)")
